# %%
from google.colab import drive
drive.mount('/content/gdrive')
#drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
root_path = '/content/gdrive/My Drive/Proyectos/Conferences/2020/Russia-AspireToScience/Resources/GO-Bot-DRL_Fork'  #change dir to your project folder
sys.path.insert(0, root_path)

# %%
from user_simulator import UserSimulator
from error_model_controller import ErrorModelController
from dqn_agent import DQNAgent
from state_tracker import StateTracker
import pickle, argparse, json, math
from utils import remove_empty_slots, timeprint
from user import User
from time import time
import datetime

# %%
# %cd "gdrive/My Drive/Proyectos/Conferences/2020/Russia-AspireToScience/Resources/GO-Bot-DRL_Fork"
# Out:
# /content/gdrive/My Drive/Proyectos/Conferences/2020/Russia-AspireToScience/Resources/GO-Bot-DRL_Fork

# %%
# Can provide constants file path in args OR run it as is and change 'CONSTANTS_FILE_PATH' below
# 1) In terminal: python train.py --constants_path "constants.json"
# 2) Run this file as is
#parser = argparse.ArgumentParser()
#parser.add_argument('--constants_path', dest='constants_path', type=str, default='')
#args = parser.parse_args()
#params = vars(args)

# Load constants json into dict

constants_file = 'constants.json'

with open(constants_file) as f:
    constants = json.load(f)

print("CONSTANTS:")
print(json.dumps(constants, indent=4, sort_keys=True))


# Load file path constants
file_path_dict = constants['db_file_paths']
DATABASE_FILE_PATH = file_path_dict['database']
DICT_FILE_PATH = file_path_dict['dict']
USER_GOALS_FILE_PATH = file_path_dict['user_goals']

# Load run constants
run_dict = constants['run']
USE_USERSIM = run_dict['usersim']
WARMUP_MEM = run_dict['warmup_mem']
NUM_EP_TRAIN = run_dict['num_ep_run']
TRAIN_FREQ = run_dict['train_freq']
MAX_ROUND_NUM = run_dict['max_round_num']
SUCCESS_RATE_THRESHOLD = run_dict['success_rate_threshold']

# Load movie DB
# Note: If you get an unpickling error here then run 'pickle_converter.py' and it should fix it
database = pickle.load(open(DATABASE_FILE_PATH, 'rb'), encoding='latin1')

# Clean DB
remove_empty_slots(database)

# Load movie dict
db_dict = pickle.load(open(DICT_FILE_PATH, 'rb'), encoding='latin1')

# Load goal File
user_goals = pickle.load(open(USER_GOALS_FILE_PATH, 'rb'), encoding='latin1')

# Init. Objects
if USE_USERSIM:
    user = UserSimulator(user_goals, constants, database)
else:
    user = User(constants)
emc = ErrorModelController(db_dict, constants)
state_tracker = StateTracker(database, constants)

# Initialize agent
dqn_agent = DQNAgent(state_tracker.get_state_size(), constants)
# Out:
# CONSTANTS:
# {
#     "agent": {
#         "batch_size": 16,
#         "dqn_hidden_size": 80,
#         "epsilon_init": 0.0,
#         "gamma": 0.9,
#         "learning_rate": 0.001,
#         "load_weights_file_path": "",
#         "max_mem_size": 500000,
#         "save_weights_file_path": "",
#         "vanilla": true
#     },
#     "db_file_paths": {
#         "database": "data/movie_db.pkl",
#         "dict": "data/movie_dict.pkl",
#         "user_goals": "data/movie_user_goals.pkl"
#     },
#     "emc": {
#         "intent_error_prob": 0.0,
#         "slot_error_mode": 0,
#         "slot_error_prob": 0.05
#     },
#     "run": {
#         "max_round_num": 20,
#         "num_ep_run": 40000,
#         "success_rate_threshold": 0.3,
#         "train_freq": 100,
#         "usersim": true,
#         "warmup_mem": 1000
#     }
# }

# %%
def run_round(state, warmup=False):
    # 1) Agent takes action given state tracker's representation of dialogue (state)
    agent_action_index, agent_action = dqn_agent.get_action(state, use_rule=warmup)
    # 2) Update state tracker with the agent's action
    state_tracker.update_state_agent(agent_action)
    # 3) User takes action given agent action
    user_action, reward, done, success = user.step(agent_action)
    if not done:
        # 4) Infuse error into semantic frame level of user action
        emc.infuse_error(user_action)
    # 5) Update state tracker with user action
    state_tracker.update_state_user(user_action)
    # 6) Get next state and add experience
    next_state = state_tracker.get_state(done)
    dqn_agent.add_experience(state, agent_action_index, reward, next_state, done)

    return next_state, reward, done, success


def warmup_run():
    """
    Runs the warmup stage of training which is used to fill the agents memory.

    The agent uses it's rule-based policy to make actions. The agent's memory is filled as this runs.
    Loop terminates when the size of the memory is equal to WARMUP_MEM or when the memory buffer is full.

    """

    print('Warmup Started...')
    total_step = 0
    while total_step != WARMUP_MEM and not dqn_agent.is_memory_full():
        # Reset episode
        episode_reset()
        done = False
        # Get initial state from state tracker
        state = state_tracker.get_state()
        while not done:
            next_state, _, done, _ = run_round(state, warmup=True)
            total_step += 1
            state = next_state

    print('...Warmup Ended')

# %%
def train_run():
    """
    Runs the loop that trains the agent.

    Trains the agent on the goal-oriented chatbot task. Training of the agent's neural network occurs every episode that
    TRAIN_FREQ is a multiple of. Terminates when the episode reaches NUM_EP_TRAIN.

    """

    print('Training Started...\n')
    print('at ', str(datetime.datetime.now()), '\n')
    episode = 0
    period_reward_total = 0
    period_success_total = 0
    success_rate_best = 0.0
    t_train_start = time()
    t_ep_start = time()
    
    while episode < NUM_EP_TRAIN:
        episode_reset()
        episode += 1
        done = False
        state = state_tracker.get_state()
        
        steps = 0
        while not done:
            steps += 1
            next_state, reward, done, success = run_round(state)
            period_reward_total += reward
            state = next_state

        period_success_total += success
  
        
        # Train
        if episode % TRAIN_FREQ == 0:
            t_ep = (time()-t_ep_start)
            
            print("EP: %d \tSteps: %d \tMemoryIndex: %d \tTime (ep_freq): %s \tTime (total): %s" % (episode, steps , dqn_agent.memory_index, timeprint(t_ep), timeprint(time()-t_train_start)))
            #print("EP: ", episode, "\tSteps: ", steps, "\nMemoryIndex:", dqn_agent.memory_index)        
            # Check success rate
            success_rate = period_success_total / TRAIN_FREQ
            avg_reward = period_reward_total / TRAIN_FREQ
            # Flush
            if success_rate >= success_rate_best and success_rate >= SUCCESS_RATE_THRESHOLD:
                dqn_agent.empty_memory()
            # Update current best success rate
            if success_rate > success_rate_best:
                print('Episode: {} NEW BEST SUCCESS RATE: {} Avg Reward: {}' .format(episode, success_rate, avg_reward))
                success_rate_best = success_rate
                dqn_agent.save_weights()
            period_success_total = 0
            period_reward_total = 0
            # Copy
            dqn_agent.copy()
            # Train
            dqn_agent.train()
            t_ep_start = time()
    print('...Training Ended')
    print('at ', str(datetime.datetime.now()), '\n')

def episode_reset():
    """
    Resets the episode/conversation in the warmup and training loops.

    Called in warmup and train to reset the state tracker, user and agent. Also get's the initial user action.

    """

    # First reset the state tracker
    state_tracker.reset()
    # Then pick an init user action
    user_action = user.reset()
    # Infuse with error
    emc.infuse_error(user_action)
    # And update state tracker
    state_tracker.update_state_user(user_action)
    # Finally, reset agent
    dqn_agent.reset()

# %%
warmup_run()
train_run()
# Out:
# Warmup Started...
# ...Warmup Ended
# Training Started...
#
# at  2020-05-01 18:09:28.499610
#
# EP: 100 	Steps: 20 	MemoryIndex: 3000 	Time (ep_freq): 0:00:02.93 	Time (total): 0:00:02.93
# EP: 200 	Steps: 20 	MemoryIndex: 5000 	Time (ep_freq): 0:00:02.46 	Time (total): 0:00:06.47
# EP: 300 	Steps: 20 	MemoryIndex: 7000 	Time (ep_freq): 0:00:02.17 	Time (total): 0:00:09.58
# EP: 400 	Steps: 20 	MemoryIndex: 8893 	Time (ep_freq): 0:00:02.64 	Time (total): 0:00:13.49
# EP: 500 	Steps: 20 	MemoryIndex: 10573 	Time (ep_freq): 0:00:02.01 	Time (total): 0:00:17.09
# EP: 600 	Steps: 20 	MemoryIndex: 12561 	Time (ep_freq): 0:00:01.79 	Time (total): 0:00:20.79
# EP: 700 	Steps: 20 	MemoryIndex: 14561 	Time (ep_freq): 0:00:03.25 	Time (total): 0:00:26.31
# EP: 800 	Steps: 20 	MemoryIndex: 16561 	Time (ep_freq): 0:00:02.52 	Time (total): 0:00:31.50
# EP: 900 	Steps: 20 	MemoryIndex: 17995 	Time (ep_freq): 0:00:01.91 	Time (total): 0:00:36.36
# EP: 1000 	Steps: 20 	MemoryIndex: 19995 	Time (ep_freq): 0:00:01.78 	Time (total): 0:00:41.37
# EP: 1100 	Steps: 20 	MemoryIndex: 21995 	Time (ep_freq): 0:00:02.34 	Time (total): 0:00:47.30
# EP: 1200 	Steps: 20 	MemoryIndex: 23995 	Time (ep_freq): 0:00:02.35 	Time (total): 0:00:53.57
# EP: 1300 	Steps: 20 	MemoryIndex: 25995 	Time (ep_freq): 0:00:02.26 	Time (total): 0:01:00.13
# EP: 1400 	Steps: 20 	MemoryIndex: 27993 	Time (ep_freq): 0:00:02.38 	Time (total): 0:01:07.19
# Episode: 1400 NEW BEST SUCCESS RATE: 0.02 Avg Reward: -38.78
# EP: 1500 	Steps: 20 	MemoryIndex: 29944 	Time (ep_freq): 0:00:02.31 	Time (total): 0:01:14.53
# Episode: 1500 NEW BEST SUCCESS RATE: 0.26 Avg Reward: -23.91
# EP: 1600 	Steps: 20 	MemoryIndex: 31398 	Time (ep_freq): 0:00:01.60 	Time (total): 0:01:21.50
# EP: 1700 	Steps: 20 	MemoryIndex: 33111 	Time (ep_freq): 0:00:02.14 	Time (total): 0:01:29.25
# EP: 1800 	Steps: 19 	MemoryIndex: 35013 	Time (ep_freq): 0:00:01.98 	Time (total): 0:01:37.21
# EP: 1900 	Steps: 20 	MemoryIndex: 36886 	Time (ep_freq): 0:00:02.20 	Time (total): 0:01:45.74
# Episode: 1900 NEW BEST SUCCESS RATE: 0.33 Avg Reward: -18.93
# EP: 2000 	Steps: 20 	MemoryIndex: 1864 	Time (ep_freq): 0:00:02.12 	Time (total): 0:01:47.90
# EP: 2100 	Steps: 20 	MemoryIndex: 3469 	Time (ep_freq): 0:00:01.67 	Time (total): 0:01:49.91
# EP: 2200 	Steps: 20 	MemoryIndex: 5302 	Time (ep_freq): 0:00:02.04 	Time (total): 0:01:52.59
# Episode: 2200 NEW BEST SUCCESS RATE: 0.43 Avg Reward: -12.53
# EP: 2300 	Steps: 15 	MemoryIndex: 1853 	Time (ep_freq): 0:00:02.00 	Time (total): 0:01:54.60
# EP: 2400 	Steps: 20 	MemoryIndex: 3274 	Time (ep_freq): 0:00:01.61 	Time (total): 0:01:56.54
# EP: 2500 	Steps: 19 	MemoryIndex: 4823 	Time (ep_freq): 0:00:01.87 	Time (total): 0:01:59.08
# EP: 2600 	Steps: 12 	MemoryIndex: 6229 	Time (ep_freq): 0:00:01.65 	Time (total): 0:02:01.69
# EP: 2700 	Steps: 6 	MemoryIndex: 7590 	Time (ep_freq): 0:00:01.69 	Time (total): 0:02:04.51
# Episode: 2700 NEW BEST SUCCESS RATE: 0.44 Avg Reward: -7.21
# EP: 2800 	Steps: 20 	MemoryIndex: 1386 	Time (ep_freq): 0:00:01.63 	Time (total): 0:02:06.16
# Episode: 2800 NEW BEST SUCCESS RATE: 0.47 Avg Reward: -5.66
# EP: 2900 	Steps: 6 	MemoryIndex: 1335 	Time (ep_freq): 0:00:01.54 	Time (total): 0:02:07.70
# EP: 3000 	Steps: 19 	MemoryIndex: 2727 	Time (ep_freq): 0:00:01.83 	Time (total): 0:02:09.78
# EP: 3100 	Steps: 7 	MemoryIndex: 3890 	Time (ep_freq): 0:00:01.38 	Time (total): 0:02:11.65
# EP: 3200 	Steps: 20 	MemoryIndex: 5542 	Time (ep_freq): 0:00:01.74 	Time (total): 0:02:14.12
# EP: 3300 	Steps: 19 	MemoryIndex: 7141 	Time (ep_freq): 0:00:01.85 	Time (total): 0:02:16.98
# EP: 3400 	Steps: 7 	MemoryIndex: 8522 	Time (ep_freq): 0:00:01.68 	Time (total): 0:02:19.96
# EP: 3500 	Steps: 5 	MemoryIndex: 9804 	Time (ep_freq): 0:00:01.41 	Time (total): 0:02:22.92
# EP: 3600 	Steps: 16 	MemoryIndex: 11057 	Time (ep_freq): 0:00:01.56 	Time (total): 0:02:26.27
# EP: 3700 	Steps: 20 	MemoryIndex: 12315 	Time (ep_freq): 0:00:01.47 	Time (total): 0:02:29.74
# Episode: 3700 NEW BEST SUCCESS RATE: 0.49 Avg Reward: -3.18
# EP: 3800 	Steps: 20 	MemoryIndex: 1164 	Time (ep_freq): 0:00:01.32 	Time (total): 0:02:31.07
# Episode: 3800 NEW BEST SUCCESS RATE: 0.58 Avg Reward: 3.16
# EP: 3900 	Steps: 6 	MemoryIndex: 1145 	Time (ep_freq): 0:00:01.27 	Time (total): 0:02:32.35
# EP: 4000 	Steps: 6 	MemoryIndex: 1128 	Time (ep_freq): 0:00:01.18 	Time (total): 0:02:33.54
# EP: 4100 	Steps: 7 	MemoryIndex: 2576 	Time (ep_freq): 0:00:01.61 	Time (total): 0:02:35.36
# EP: 4200 	Steps: 8 	MemoryIndex: 3954 	Time (ep_freq): 0:00:01.85 	Time (total): 0:02:37.69
# EP: 4300 	Steps: 6 	MemoryIndex: 5096 	Time (ep_freq): 0:00:01.31 	Time (total): 0:02:39.72
# EP: 4400 	Steps: 20 	MemoryIndex: 6418 	Time (ep_freq): 0:00:01.75 	Time (total): 0:02:42.39
# EP: 4500 	Steps: 6 	MemoryIndex: 7623 	Time (ep_freq): 0:00:01.70 	Time (total): 0:02:45.27
# EP: 4600 	Steps: 20 	MemoryIndex: 8730 	Time (ep_freq): 0:00:01.31 	Time (total): 0:02:47.97
# Episode: 4600 NEW BEST SUCCESS RATE: 0.63 Avg Reward: 6.73
# EP: 4700 	Steps: 20 	MemoryIndex: 1140 	Time (ep_freq): 0:00:01.40 	Time (total): 0:02:49.38
# EP: 4800 	Steps: 7 	MemoryIndex: 2058 	Time (ep_freq): 0:00:01.08 	Time (total): 0:02:50.67
# EP: 4900 	Steps: 6 	MemoryIndex: 3396 	Time (ep_freq): 0:00:01.63 	Time (total): 0:02:52.69
# EP: 5000 	Steps: 7 	MemoryIndex: 4363 	Time (ep_freq): 0:00:01.21 	Time (total): 0:02:54.52
# EP: 5100 	Steps: 20 	MemoryIndex: 5514 	Time (ep_freq): 0:00:01.44 	Time (total): 0:02:56.75
# EP: 5200 	Steps: 6 	MemoryIndex: 6743 	Time (ep_freq): 0:00:01.51 	Time (total): 0:02:59.26
# EP: 5300 	Steps: 6 	MemoryIndex: 7834 	Time (ep_freq): 0:00:01.44 	Time (total): 0:03:01.92
# EP: 5400 	Steps: 6 	MemoryIndex: 9225 	Time (ep_freq): 0:00:01.66 	Time (total): 0:03:05.00
# EP: 5500 	Steps: 10 	MemoryIndex: 10401 	Time (ep_freq): 0:00:01.55 	Time (total): 0:03:08.21
# EP: 5600 	Steps: 20 	MemoryIndex: 11537 	Time (ep_freq): 0:00:01.36 	Time (total): 0:03:11.44
# EP: 5700 	Steps: 6 	MemoryIndex: 12708 	Time (ep_freq): 0:00:01.49 	Time (total): 0:03:15.00
# EP: 5800 	Steps: 20 	MemoryIndex: 13751 	Time (ep_freq): 0:00:01.19 	Time (total): 0:03:18.51
# Episode: 5800 NEW BEST SUCCESS RATE: 0.7 Avg Reward: 11.57
# EP: 5900 	Steps: 9 	MemoryIndex: 1178 	Time (ep_freq): 0:00:01.36 	Time (total): 0:03:19.89
# EP: 6000 	Steps: 7 	MemoryIndex: 2249 	Time (ep_freq): 0:00:01.27 	Time (total): 0:03:21.38
# EP: 6100 	Steps: 20 	MemoryIndex: 3370 	Time (ep_freq): 0:00:01.38 	Time (total): 0:03:23.17
# EP: 6200 	Steps: 7 	MemoryIndex: 4472 	Time (ep_freq): 0:00:01.39 	Time (total): 0:03:25.19
# EP: 6300 	Steps: 7 	MemoryIndex: 5671 	Time (ep_freq): 0:00:01.36 	Time (total): 0:03:27.35
# EP: 6400 	Steps: 7 	MemoryIndex: 6751 	Time (ep_freq): 0:00:01.29 	Time (total): 0:03:29.66
# EP: 6500 	Steps: 20 	MemoryIndex: 7714 	Time (ep_freq): 0:00:01.20 	Time (total): 0:03:32.06
# EP: 6600 	Steps: 6 	MemoryIndex: 1088 	Time (ep_freq): 0:00:01.25 	Time (total): 0:03:33.32
# EP: 6700 	Steps: 20 	MemoryIndex: 2065 	Time (ep_freq): 0:00:01.30 	Time (total): 0:03:34.83
# Episode: 6700 NEW BEST SUCCESS RATE: 0.73 Avg Reward: 14.03
# EP: 6800 	Steps: 10 	MemoryIndex: 1050 	Time (ep_freq): 0:00:01.47 	Time (total): 0:03:36.30
# EP: 6900 	Steps: 6 	MemoryIndex: 2083 	Time (ep_freq): 0:00:01.16 	Time (total): 0:03:37.66
# EP: 7000 	Steps: 6 	MemoryIndex: 2982 	Time (ep_freq): 0:00:01.09 	Time (total): 0:03:39.13
# EP: 7100 	Steps: 7 	MemoryIndex: 4243 	Time (ep_freq): 0:00:01.69 	Time (total): 0:03:41.36
# EP: 7200 	Steps: 16 	MemoryIndex: 5248 	Time (ep_freq): 0:00:01.36 	Time (total): 0:03:43.50
# EP: 7300 	Steps: 6 	MemoryIndex: 6190 	Time (ep_freq): 0:00:01.33 	Time (total): 0:03:45.76
# EP: 7400 	Steps: 20 	MemoryIndex: 7310 	Time (ep_freq): 0:00:01.60 	Time (total): 0:03:48.49
# EP: 7500 	Steps: 6 	MemoryIndex: 8341 	Time (ep_freq): 0:00:01.34 	Time (total): 0:03:51.14
# EP: 7600 	Steps: 6 	MemoryIndex: 9097 	Time (ep_freq): 0:00:00.94 	Time (total): 0:03:53.57
# Episode: 7600 NEW BEST SUCCESS RATE: 0.78 Avg Reward: 19.24
# EP: 7700 	Steps: 6 	MemoryIndex: 799 	Time (ep_freq): 0:00:01.00 	Time (total): 0:03:54.58
# EP: 7800 	Steps: 6 	MemoryIndex: 1639 	Time (ep_freq): 0:00:01.12 	Time (total): 0:03:55.85
# EP: 7900 	Steps: 20 	MemoryIndex: 2595 	Time (ep_freq): 0:00:01.17 	Time (total): 0:03:57.33
# EP: 8000 	Steps: 6 	MemoryIndex: 3472 	Time (ep_freq): 0:00:00.97 	Time (total): 0:03:58.78
# EP: 8100 	Steps: 6 	MemoryIndex: 4271 	Time (ep_freq): 0:00:00.96 	Time (total): 0:04:00.38
# EP: 8200 	Steps: 7 	MemoryIndex: 5174 	Time (ep_freq): 0:00:01.10 	Time (total): 0:04:02.26
# EP: 8300 	Steps: 6 	MemoryIndex: 5988 	Time (ep_freq): 0:00:00.89 	Time (total): 0:04:04.08
# EP: 8400 	Steps: 20 	MemoryIndex: 6925 	Time (ep_freq): 0:00:01.02 	Time (total): 0:04:06.17
# EP: 8500 	Steps: 16 	MemoryIndex: 7860 	Time (ep_freq): 0:00:00.93 	Time (total): 0:04:08.36
# Episode: 8500 NEW BEST SUCCESS RATE: 0.81 Avg Reward: 19.25
# EP: 8600 	Steps: 7 	MemoryIndex: 997 	Time (ep_freq): 0:00:01.14 	Time (total): 0:04:09.52
# EP: 8700 	Steps: 6 	MemoryIndex: 1980 	Time (ep_freq): 0:00:01.19 	Time (total): 0:04:10.88
# EP: 8800 	Steps: 6 	MemoryIndex: 2845 	Time (ep_freq): 0:00:01.03 	Time (total): 0:04:12.30
# EP: 8900 	Steps: 20 	MemoryIndex: 3759 	Time (ep_freq): 0:00:01.06 	Time (total): 0:04:13.88
# EP: 9000 	Steps: 6 	MemoryIndex: 4728 	Time (ep_freq): 0:00:01.22 	Time (total): 0:04:15.80
# EP: 9100 	Steps: 6 	MemoryIndex: 5594 	Time (ep_freq): 0:00:00.95 	Time (total): 0:04:17.61
# EP: 9200 	Steps: 6 	MemoryIndex: 6494 	Time (ep_freq): 0:00:01.03 	Time (total): 0:04:19.63
# EP: 9300 	Steps: 16 	MemoryIndex: 7437 	Time (ep_freq): 0:00:01.11 	Time (total): 0:04:21.92
# EP: 9400 	Steps: 20 	MemoryIndex: 8435 	Time (ep_freq): 0:00:01.19 	Time (total): 0:04:24.45
# EP: 9500 	Steps: 20 	MemoryIndex: 9353 	Time (ep_freq): 0:00:01.05 	Time (total): 0:04:27.03
# EP: 9600 	Steps: 20 	MemoryIndex: 10368 	Time (ep_freq): 0:00:01.31 	Time (total): 0:04:30.04
# EP: 9700 	Steps: 6 	MemoryIndex: 11213 	Time (ep_freq): 0:00:01.04 	Time (total): 0:04:32.92
# EP: 9800 	Steps: 7 	MemoryIndex: 12075 	Time (ep_freq): 0:00:01.02 	Time (total): 0:04:35.95
# EP: 9900 	Steps: 6 	MemoryIndex: 12917 	Time (ep_freq): 0:00:00.99 	Time (total): 0:04:39.10
# EP: 10000 	Steps: 7 	MemoryIndex: 13782 	Time (ep_freq): 0:00:01.01 	Time (total): 0:04:42.43
# EP: 10100 	Steps: 6 	MemoryIndex: 14674 	Time (ep_freq): 0:00:01.09 	Time (total): 0:04:45.99
# EP: 10200 	Steps: 6 	MemoryIndex: 15735 	Time (ep_freq): 0:00:01.32 	Time (total): 0:04:49.93
# EP: 10300 	Steps: 6 	MemoryIndex: 16673 	Time (ep_freq): 0:00:01.08 	Time (total): 0:04:53.84
# EP: 10400 	Steps: 7 	MemoryIndex: 17560 	Time (ep_freq): 0:00:01.05 	Time (total): 0:04:57.91
# EP: 10500 	Steps: 6 	MemoryIndex: 18412 	Time (ep_freq): 0:00:00.95 	Time (total): 0:05:01.99
# EP: 10600 	Steps: 6 	MemoryIndex: 19278 	Time (ep_freq): 0:00:01.05 	Time (total): 0:05:06.33
# EP: 10700 	Steps: 6 	MemoryIndex: 20240 	Time (ep_freq): 0:00:01.35 	Time (total): 0:05:11.47
# EP: 10800 	Steps: 20 	MemoryIndex: 21196 	Time (ep_freq): 0:00:01.17 	Time (total): 0:05:16.62
# Episode: 10800 NEW BEST SUCCESS RATE: 0.82 Avg Reward: 19.64
# EP: 10900 	Steps: 6 	MemoryIndex: 911 	Time (ep_freq): 0:00:01.18 	Time (total): 0:05:17.83
# EP: 11000 	Steps: 6 	MemoryIndex: 1654 	Time (ep_freq): 0:00:00.81 	Time (total): 0:05:18.82
# Episode: 11000 NEW BEST SUCCESS RATE: 0.9 Avg Reward: 26.57
# EP: 11100 	Steps: 20 	MemoryIndex: 887 	Time (ep_freq): 0:00:01.00 	Time (total): 0:05:19.83
# EP: 11200 	Steps: 6 	MemoryIndex: 1725 	Time (ep_freq): 0:00:00.92 	Time (total): 0:05:20.91
# EP: 11300 	Steps: 20 	MemoryIndex: 2518 	Time (ep_freq): 0:00:00.89 	Time (total): 0:05:22.12
# EP: 11400 	Steps: 6 	MemoryIndex: 3422 	Time (ep_freq): 0:00:01.04 	Time (total): 0:05:23.60
# EP: 11500 	Steps: 20 	MemoryIndex: 4342 	Time (ep_freq): 0:00:01.11 	Time (total): 0:05:25.35
# EP: 11600 	Steps: 20 	MemoryIndex: 5152 	Time (ep_freq): 0:00:00.98 	Time (total): 0:05:27.11
# EP: 11700 	Steps: 6 	MemoryIndex: 5972 	Time (ep_freq): 0:00:00.89 	Time (total): 0:05:28.94
# EP: 11800 	Steps: 6 	MemoryIndex: 6808 	Time (ep_freq): 0:00:00.94 	Time (total): 0:05:30.97
# EP: 11900 	Steps: 6 	MemoryIndex: 7641 	Time (ep_freq): 0:00:00.96 	Time (total): 0:05:33.16
# EP: 12000 	Steps: 6 	MemoryIndex: 8437 	Time (ep_freq): 0:00:00.91 	Time (total): 0:05:35.45
# EP: 12100 	Steps: 6 	MemoryIndex: 9197 	Time (ep_freq): 0:00:00.75 	Time (total): 0:05:37.72
# EP: 12200 	Steps: 6 	MemoryIndex: 10022 	Time (ep_freq): 0:00:01.03 	Time (total): 0:05:40.41
# EP: 12300 	Steps: 6 	MemoryIndex: 10850 	Time (ep_freq): 0:00:00.99 	Time (total): 0:05:43.21
# EP: 12400 	Steps: 20 	MemoryIndex: 11622 	Time (ep_freq): 0:00:00.82 	Time (total): 0:05:46.00
# EP: 12500 	Steps: 5 	MemoryIndex: 12398 	Time (ep_freq): 0:00:00.85 	Time (total): 0:05:48.95
# EP: 12600 	Steps: 6 	MemoryIndex: 13197 	Time (ep_freq): 0:00:00.86 	Time (total): 0:05:52.04
# EP: 12700 	Steps: 6 	MemoryIndex: 13956 	Time (ep_freq): 0:00:00.84 	Time (total): 0:05:55.25
# EP: 12800 	Steps: 6 	MemoryIndex: 14791 	Time (ep_freq): 0:00:00.96 	Time (total): 0:05:58.72
# EP: 12900 	Steps: 6 	MemoryIndex: 15615 	Time (ep_freq): 0:00:00.92 	Time (total): 0:06:02.29
# EP: 13000 	Steps: 6 	MemoryIndex: 16439 	Time (ep_freq): 0:00:00.86 	Time (total): 0:06:05.97
# EP: 13100 	Steps: 6 	MemoryIndex: 17280 	Time (ep_freq): 0:00:00.89 	Time (total): 0:06:09.85
# EP: 13200 	Steps: 6 	MemoryIndex: 18116 	Time (ep_freq): 0:00:00.97 	Time (total): 0:06:13.96
# EP: 13300 	Steps: 6 	MemoryIndex: 18960 	Time (ep_freq): 0:00:00.93 	Time (total): 0:06:18.17
# EP: 13400 	Steps: 6 	MemoryIndex: 19722 	Time (ep_freq): 0:00:00.88 	Time (total): 0:06:22.48
# EP: 13500 	Steps: 6 	MemoryIndex: 20528 	Time (ep_freq): 0:00:00.91 	Time (total): 0:06:26.97
# EP: 13600 	Steps: 6 	MemoryIndex: 21366 	Time (ep_freq): 0:00:01.03 	Time (total): 0:06:31.73
# EP: 13700 	Steps: 8 	MemoryIndex: 22193 	Time (ep_freq): 0:00:01.04 	Time (total): 0:06:36.67
# EP: 13800 	Steps: 8 	MemoryIndex: 22969 	Time (ep_freq): 0:00:00.86 	Time (total): 0:06:41.52
# EP: 13900 	Steps: 6 	MemoryIndex: 23738 	Time (ep_freq): 0:00:00.85 	Time (total): 0:06:46.51
# EP: 14000 	Steps: 6 	MemoryIndex: 24546 	Time (ep_freq): 0:00:01.00 	Time (total): 0:06:51.78
# EP: 14100 	Steps: 6 	MemoryIndex: 25366 	Time (ep_freq): 0:00:00.83 	Time (total): 0:06:57.04
# EP: 14200 	Steps: 8 	MemoryIndex: 26216 	Time (ep_freq): 0:00:00.95 	Time (total): 0:07:02.54
# EP: 14300 	Steps: 8 	MemoryIndex: 27004 	Time (ep_freq): 0:00:01.02 	Time (total): 0:07:08.66
# EP: 14400 	Steps: 9 	MemoryIndex: 27864 	Time (ep_freq): 0:00:01.00 	Time (total): 0:07:14.50
# EP: 14500 	Steps: 6 	MemoryIndex: 28809 	Time (ep_freq): 0:00:01.15 	Time (total): 0:07:20.68
# EP: 14600 	Steps: 11 	MemoryIndex: 29618 	Time (ep_freq): 0:00:00.92 	Time (total): 0:07:26.76
# EP: 14700 	Steps: 6 	MemoryIndex: 30403 	Time (ep_freq): 0:00:00.89 	Time (total): 0:07:32.97
# EP: 14800 	Steps: 6 	MemoryIndex: 31214 	Time (ep_freq): 0:00:00.86 	Time (total): 0:07:39.33
# EP: 14900 	Steps: 20 	MemoryIndex: 31996 	Time (ep_freq): 0:00:00.86 	Time (total): 0:07:45.81
# EP: 15000 	Steps: 20 	MemoryIndex: 32760 	Time (ep_freq): 0:00:00.83 	Time (total): 0:07:52.36
# EP: 15100 	Steps: 6 	MemoryIndex: 33535 	Time (ep_freq): 0:00:00.85 	Time (total): 0:07:59.08
# EP: 15200 	Steps: 20 	MemoryIndex: 34388 	Time (ep_freq): 0:00:01.05 	Time (total): 0:08:06.14
# EP: 15300 	Steps: 20 	MemoryIndex: 35192 	Time (ep_freq): 0:00:00.95 	Time (total): 0:08:13.28
# EP: 15400 	Steps: 6 	MemoryIndex: 35926 	Time (ep_freq): 0:00:00.81 	Time (total): 0:08:20.40
# EP: 15500 	Steps: 11 	MemoryIndex: 820 	Time (ep_freq): 0:00:00.99 	Time (total): 0:08:21.42
# EP: 15600 	Steps: 5 	MemoryIndex: 1637 	Time (ep_freq): 0:00:00.91 	Time (total): 0:08:22.48
# EP: 15700 	Steps: 6 	MemoryIndex: 2443 	Time (ep_freq): 0:00:00.91 	Time (total): 0:08:23.70
# EP: 15800 	Steps: 6 	MemoryIndex: 3200 	Time (ep_freq): 0:00:00.85 	Time (total): 0:08:25.00
# EP: 15900 	Steps: 20 	MemoryIndex: 3941 	Time (ep_freq): 0:00:00.86 	Time (total): 0:08:26.44
# EP: 16000 	Steps: 8 	MemoryIndex: 4782 	Time (ep_freq): 0:00:00.89 	Time (total): 0:08:28.05
# EP: 16100 	Steps: 20 	MemoryIndex: 5583 	Time (ep_freq): 0:00:00.88 	Time (total): 0:08:29.80
# EP: 16200 	Steps: 5 	MemoryIndex: 6385 	Time (ep_freq): 0:00:01.05 	Time (total): 0:08:31.87
# EP: 16300 	Steps: 6 	MemoryIndex: 7231 	Time (ep_freq): 0:00:01.04 	Time (total): 0:08:34.06
# EP: 16400 	Steps: 8 	MemoryIndex: 8020 	Time (ep_freq): 0:00:00.80 	Time (total): 0:08:36.14
# EP: 16500 	Steps: 6 	MemoryIndex: 8781 	Time (ep_freq): 0:00:00.79 	Time (total): 0:08:38.39
# EP: 16600 	Steps: 20 	MemoryIndex: 9579 	Time (ep_freq): 0:00:00.88 	Time (total): 0:08:40.86
# EP: 16700 	Steps: 8 	MemoryIndex: 10433 	Time (ep_freq): 0:00:00.97 	Time (total): 0:08:43.56
# EP: 16800 	Steps: 7 	MemoryIndex: 11195 	Time (ep_freq): 0:00:00.85 	Time (total): 0:08:46.29
# EP: 16900 	Steps: 6 	MemoryIndex: 782 	Time (ep_freq): 0:00:00.89 	Time (total): 0:08:47.20
# EP: 17000 	Steps: 6 	MemoryIndex: 1598 	Time (ep_freq): 0:00:00.89 	Time (total): 0:08:48.24
# EP: 17100 	Steps: 6 	MemoryIndex: 2392 	Time (ep_freq): 0:00:00.92 	Time (total): 0:08:49.45
# EP: 17200 	Steps: 6 	MemoryIndex: 3233 	Time (ep_freq): 0:00:00.91 	Time (total): 0:08:50.81
# EP: 17300 	Steps: 5 	MemoryIndex: 4056 	Time (ep_freq): 0:00:00.81 	Time (total): 0:08:52.22
# EP: 17400 	Steps: 5 	MemoryIndex: 4860 	Time (ep_freq): 0:00:00.82 	Time (total): 0:08:53.78
# EP: 17500 	Steps: 6 	MemoryIndex: 5703 	Time (ep_freq): 0:00:00.85 	Time (total): 0:08:55.51
# EP: 17600 	Steps: 8 	MemoryIndex: 6508 	Time (ep_freq): 0:00:00.81 	Time (total): 0:08:57.35
# EP: 17700 	Steps: 6 	MemoryIndex: 7328 	Time (ep_freq): 0:00:00.81 	Time (total): 0:08:59.34
# EP: 17800 	Steps: 7 	MemoryIndex: 8103 	Time (ep_freq): 0:00:00.83 	Time (total): 0:09:01.51
# EP: 17900 	Steps: 7 	MemoryIndex: 8947 	Time (ep_freq): 0:00:00.97 	Time (total): 0:09:03.94
# EP: 18000 	Steps: 7 	MemoryIndex: 9684 	Time (ep_freq): 0:00:00.70 	Time (total): 0:09:06.25
# Episode: 18000 NEW BEST SUCCESS RATE: 0.91 Avg Reward: 27.23
# EP: 18100 	Steps: 8 	MemoryIndex: 731 	Time (ep_freq): 0:00:00.76 	Time (total): 0:09:07.03
# EP: 18200 	Steps: 7 	MemoryIndex: 841 	Time (ep_freq): 0:00:00.83 	Time (total): 0:09:07.87
# EP: 18300 	Steps: 6 	MemoryIndex: 1650 	Time (ep_freq): 0:00:00.87 	Time (total): 0:09:08.90
# EP: 18400 	Steps: 6 	MemoryIndex: 2388 	Time (ep_freq): 0:00:00.70 	Time (total): 0:09:09.90
# EP: 18500 	Steps: 5 	MemoryIndex: 757 	Time (ep_freq): 0:00:00.72 	Time (total): 0:09:10.63
# EP: 18600 	Steps: 5 	MemoryIndex: 1510 	Time (ep_freq): 0:00:00.72 	Time (total): 0:09:11.49
# EP: 18700 	Steps: 5 	MemoryIndex: 2207 	Time (ep_freq): 0:00:00.77 	Time (total): 0:09:12.55
# Episode: 18700 NEW BEST SUCCESS RATE: 0.94 Avg Reward: 29.43
# EP: 18800 	Steps: 6 	MemoryIndex: 645 	Time (ep_freq): 0:00:00.60 	Time (total): 0:09:13.15
# Episode: 18800 NEW BEST SUCCESS RATE: 0.95 Avg Reward: 30.55
# EP: 18900 	Steps: 6 	MemoryIndex: 919 	Time (ep_freq): 0:00:01.06 	Time (total): 0:09:14.22
# EP: 19000 	Steps: 6 	MemoryIndex: 1743 	Time (ep_freq): 0:00:00.86 	Time (total): 0:09:15.24
# EP: 19100 	Steps: 6 	MemoryIndex: 2621 	Time (ep_freq): 0:00:01.04 	Time (total): 0:09:16.61
# EP: 19200 	Steps: 6 	MemoryIndex: 3395 	Time (ep_freq): 0:00:00.76 	Time (total): 0:09:17.84
# EP: 19300 	Steps: 6 	MemoryIndex: 4197 	Time (ep_freq): 0:00:00.77 	Time (total): 0:09:19.23
# EP: 19400 	Steps: 7 	MemoryIndex: 5002 	Time (ep_freq): 0:00:00.89 	Time (total): 0:09:20.89
# EP: 19500 	Steps: 9 	MemoryIndex: 5792 	Time (ep_freq): 0:00:00.84 	Time (total): 0:09:22.64
# EP: 19600 	Steps: 5 	MemoryIndex: 6680 	Time (ep_freq): 0:00:00.96 	Time (total): 0:09:24.65
# EP: 19700 	Steps: 6 	MemoryIndex: 7613 	Time (ep_freq): 0:00:01.07 	Time (total): 0:09:26.94
# EP: 19800 	Steps: 20 	MemoryIndex: 8460 	Time (ep_freq): 0:00:00.87 	Time (total): 0:09:29.19
# EP: 19900 	Steps: 5 	MemoryIndex: 9227 	Time (ep_freq): 0:00:00.81 	Time (total): 0:09:31.52
# EP: 20000 	Steps: 6 	MemoryIndex: 10052 	Time (ep_freq): 0:00:00.90 	Time (total): 0:09:34.08
# EP: 20100 	Steps: 11 	MemoryIndex: 10816 	Time (ep_freq): 0:00:00.72 	Time (total): 0:09:36.62
# EP: 20200 	Steps: 6 	MemoryIndex: 11511 	Time (ep_freq): 0:00:00.68 	Time (total): 0:09:39.25
# EP: 20300 	Steps: 5 	MemoryIndex: 12289 	Time (ep_freq): 0:00:00.78 	Time (total): 0:09:42.11
# EP: 20400 	Steps: 5 	MemoryIndex: 13085 	Time (ep_freq): 0:00:00.89 	Time (total): 0:09:45.20
# EP: 20500 	Steps: 9 	MemoryIndex: 13895 	Time (ep_freq): 0:00:00.91 	Time (total): 0:09:48.46
# EP: 20600 	Steps: 8 	MemoryIndex: 14682 	Time (ep_freq): 0:00:00.83 	Time (total): 0:09:51.82
# EP: 20700 	Steps: 6 	MemoryIndex: 15492 	Time (ep_freq): 0:00:00.89 	Time (total): 0:09:55.37
# EP: 20800 	Steps: 7 	MemoryIndex: 16243 	Time (ep_freq): 0:00:00.78 	Time (total): 0:09:58.96
# EP: 20900 	Steps: 6 	MemoryIndex: 17041 	Time (ep_freq): 0:00:00.84 	Time (total): 0:10:02.70
# EP: 21000 	Steps: 6 	MemoryIndex: 17890 	Time (ep_freq): 0:00:01.03 	Time (total): 0:10:06.81
# EP: 21100 	Steps: 6 	MemoryIndex: 18694 	Time (ep_freq): 0:00:00.87 	Time (total): 0:10:10.91
# EP: 21200 	Steps: 9 	MemoryIndex: 19456 	Time (ep_freq): 0:00:00.75 	Time (total): 0:10:15.04
# EP: 21300 	Steps: 6 	MemoryIndex: 20236 	Time (ep_freq): 0:00:00.92 	Time (total): 0:10:19.50
# EP: 21400 	Steps: 8 	MemoryIndex: 21131 	Time (ep_freq): 0:00:01.24 	Time (total): 0:10:24.70
# EP: 21500 	Steps: 5 	MemoryIndex: 21873 	Time (ep_freq): 0:00:00.78 	Time (total): 0:10:29.68
# EP: 21600 	Steps: 6 	MemoryIndex: 22715 	Time (ep_freq): 0:00:00.92 	Time (total): 0:10:34.55
# EP: 21700 	Steps: 8 	MemoryIndex: 23468 	Time (ep_freq): 0:00:00.81 	Time (total): 0:10:39.46
# EP: 21800 	Steps: 6 	MemoryIndex: 24279 	Time (ep_freq): 0:00:00.82 	Time (total): 0:10:44.54
# EP: 21900 	Steps: 5 	MemoryIndex: 25030 	Time (ep_freq): 0:00:00.74 	Time (total): 0:10:49.67
# EP: 22000 	Steps: 8 	MemoryIndex: 26039 	Time (ep_freq): 0:00:01.19 	Time (total): 0:10:55.38
# EP: 22100 	Steps: 7 	MemoryIndex: 26846 	Time (ep_freq): 0:00:00.93 	Time (total): 0:11:00.99
# EP: 22200 	Steps: 6 	MemoryIndex: 27642 	Time (ep_freq): 0:00:00.87 	Time (total): 0:11:06.68
# EP: 22300 	Steps: 5 	MemoryIndex: 28324 	Time (ep_freq): 0:00:00.70 	Time (total): 0:11:12.32
# EP: 22400 	Steps: 6 	MemoryIndex: 29117 	Time (ep_freq): 0:00:00.85 	Time (total): 0:11:18.24
# EP: 22500 	Steps: 6 	MemoryIndex: 29911 	Time (ep_freq): 0:00:00.91 	Time (total): 0:11:24.38
# EP: 22600 	Steps: 6 	MemoryIndex: 30697 	Time (ep_freq): 0:00:00.84 	Time (total): 0:11:30.62
# EP: 22700 	Steps: 6 	MemoryIndex: 31461 	Time (ep_freq): 0:00:00.83 	Time (total): 0:11:36.96
# EP: 22800 	Steps: 6 	MemoryIndex: 32309 	Time (ep_freq): 0:00:00.95 	Time (total): 0:11:43.58
# EP: 22900 	Steps: 9 	MemoryIndex: 33148 	Time (ep_freq): 0:00:00.89 	Time (total): 0:11:50.27
# EP: 23000 	Steps: 13 	MemoryIndex: 33939 	Time (ep_freq): 0:00:00.82 	Time (total): 0:11:57.07
# EP: 23100 	Steps: 7 	MemoryIndex: 34690 	Time (ep_freq): 0:00:00.76 	Time (total): 0:12:03.95
# EP: 23200 	Steps: 5 	MemoryIndex: 35446 	Time (ep_freq): 0:00:00.84 	Time (total): 0:12:11.08
# EP: 23300 	Steps: 7 	MemoryIndex: 36274 	Time (ep_freq): 0:00:00.98 	Time (total): 0:12:18.89
# EP: 23400 	Steps: 5 	MemoryIndex: 36925 	Time (ep_freq): 0:00:00.65 	Time (total): 0:12:26.03
# EP: 23500 	Steps: 5 	MemoryIndex: 733 	Time (ep_freq): 0:00:00.76 	Time (total): 0:12:26.82
# EP: 23600 	Steps: 20 	MemoryIndex: 1497 	Time (ep_freq): 0:00:00.81 	Time (total): 0:12:27.77
# EP: 23700 	Steps: 5 	MemoryIndex: 2261 	Time (ep_freq): 0:00:00.85 	Time (total): 0:12:28.91
# EP: 23800 	Steps: 6 	MemoryIndex: 3046 	Time (ep_freq): 0:00:00.87 	Time (total): 0:12:30.21
# EP: 23900 	Steps: 20 	MemoryIndex: 3907 	Time (ep_freq): 0:00:00.93 	Time (total): 0:12:31.70
# EP: 24000 	Steps: 7 	MemoryIndex: 4721 	Time (ep_freq): 0:00:00.91 	Time (total): 0:12:33.31
# EP: 24100 	Steps: 6 	MemoryIndex: 5487 	Time (ep_freq): 0:00:00.81 	Time (total): 0:12:34.99
# EP: 24200 	Steps: 5 	MemoryIndex: 6289 	Time (ep_freq): 0:00:00.94 	Time (total): 0:12:36.91
# EP: 24300 	Steps: 6 	MemoryIndex: 7006 	Time (ep_freq): 0:00:00.80 	Time (total): 0:12:38.86
# EP: 24400 	Steps: 20 	MemoryIndex: 7776 	Time (ep_freq): 0:00:00.93 	Time (total): 0:12:41.04
# EP: 24500 	Steps: 6 	MemoryIndex: 8534 	Time (ep_freq): 0:00:00.86 	Time (total): 0:12:43.30
# EP: 24600 	Steps: 6 	MemoryIndex: 9250 	Time (ep_freq): 0:00:00.78 	Time (total): 0:12:45.61
# EP: 24700 	Steps: 6 	MemoryIndex: 10026 	Time (ep_freq): 0:00:00.88 	Time (total): 0:12:48.15
# EP: 24800 	Steps: 7 	MemoryIndex: 10766 	Time (ep_freq): 0:00:00.73 	Time (total): 0:12:50.69
# EP: 24900 	Steps: 7 	MemoryIndex: 11581 	Time (ep_freq): 0:00:00.96 	Time (total): 0:12:53.59
# EP: 25000 	Steps: 7 	MemoryIndex: 12338 	Time (ep_freq): 0:00:00.84 	Time (total): 0:12:56.52
# EP: 25100 	Steps: 6 	MemoryIndex: 13275 	Time (ep_freq): 0:00:01.16 	Time (total): 0:12:59.92
# EP: 25200 	Steps: 6 	MemoryIndex: 14013 	Time (ep_freq): 0:00:00.79 	Time (total): 0:13:03.10
# EP: 25300 	Steps: 5 	MemoryIndex: 14767 	Time (ep_freq): 0:00:00.78 	Time (total): 0:13:06.39
# EP: 25400 	Steps: 10 	MemoryIndex: 15502 	Time (ep_freq): 0:00:00.70 	Time (total): 0:13:09.73
# EP: 25500 	Steps: 6 	MemoryIndex: 16337 	Time (ep_freq): 0:00:00.94 	Time (total): 0:13:13.47
# EP: 25600 	Steps: 15 	MemoryIndex: 17105 	Time (ep_freq): 0:00:00.86 	Time (total): 0:13:17.28
# EP: 25700 	Steps: 6 	MemoryIndex: 17848 	Time (ep_freq): 0:00:00.77 	Time (total): 0:13:21.11
# EP: 25800 	Steps: 6 	MemoryIndex: 18675 	Time (ep_freq): 0:00:00.86 	Time (total): 0:13:25.17
# EP: 25900 	Steps: 20 	MemoryIndex: 19441 	Time (ep_freq): 0:00:00.83 	Time (total): 0:13:29.37
# EP: 26000 	Steps: 8 	MemoryIndex: 20142 	Time (ep_freq): 0:00:00.73 	Time (total): 0:13:33.58
# EP: 26100 	Steps: 20 	MemoryIndex: 20925 	Time (ep_freq): 0:00:00.88 	Time (total): 0:13:38.09
# EP: 26200 	Steps: 20 	MemoryIndex: 21709 	Time (ep_freq): 0:00:00.82 	Time (total): 0:13:42.64
# EP: 26300 	Steps: 7 	MemoryIndex: 22546 	Time (ep_freq): 0:00:00.98 	Time (total): 0:13:47.53
# EP: 26400 	Steps: 6 	MemoryIndex: 23269 	Time (ep_freq): 0:00:00.69 	Time (total): 0:13:52.25
# EP: 26500 	Steps: 6 	MemoryIndex: 23986 	Time (ep_freq): 0:00:00.72 	Time (total): 0:13:57.15
# EP: 26600 	Steps: 6 	MemoryIndex: 24778 	Time (ep_freq): 0:00:00.90 	Time (total): 0:14:02.35
# EP: 26700 	Steps: 5 	MemoryIndex: 25578 	Time (ep_freq): 0:00:00.96 	Time (total): 0:14:07.77
# EP: 26800 	Steps: 5 	MemoryIndex: 26307 	Time (ep_freq): 0:00:00.76 	Time (total): 0:14:13.13
# EP: 26900 	Steps: 20 	MemoryIndex: 27077 	Time (ep_freq): 0:00:00.75 	Time (total): 0:14:18.61
# EP: 27000 	Steps: 5 	MemoryIndex: 27830 	Time (ep_freq): 0:00:00.82 	Time (total): 0:14:24.28
# EP: 27100 	Steps: 6 	MemoryIndex: 28589 	Time (ep_freq): 0:00:00.78 	Time (total): 0:14:30.06
# EP: 27200 	Steps: 7 	MemoryIndex: 29346 	Time (ep_freq): 0:00:00.83 	Time (total): 0:14:35.99
# EP: 27300 	Steps: 5 	MemoryIndex: 30077 	Time (ep_freq): 0:00:00.77 	Time (total): 0:14:41.98
# EP: 27400 	Steps: 5 	MemoryIndex: 30851 	Time (ep_freq): 0:00:00.85 	Time (total): 0:14:48.24
# EP: 27500 	Steps: 20 	MemoryIndex: 31565 	Time (ep_freq): 0:00:00.76 	Time (total): 0:14:54.52
# EP: 27600 	Steps: 6 	MemoryIndex: 32293 	Time (ep_freq): 0:00:00.78 	Time (total): 0:15:00.97
# EP: 27700 	Steps: 5 	MemoryIndex: 33078 	Time (ep_freq): 0:00:00.92 	Time (total): 0:15:07.68
# EP: 27800 	Steps: 5 	MemoryIndex: 33795 	Time (ep_freq): 0:00:00.72 	Time (total): 0:15:14.30
# EP: 27900 	Steps: 8 	MemoryIndex: 34586 	Time (ep_freq): 0:00:00.83 	Time (total): 0:15:21.18
# EP: 28000 	Steps: 7 	MemoryIndex: 35378 	Time (ep_freq): 0:00:00.80 	Time (total): 0:15:28.20
# EP: 28100 	Steps: 6 	MemoryIndex: 36161 	Time (ep_freq): 0:00:01.04 	Time (total): 0:15:35.91
# EP: 28200 	Steps: 6 	MemoryIndex: 37029 	Time (ep_freq): 0:00:00.92 	Time (total): 0:15:43.67
# EP: 28300 	Steps: 6 	MemoryIndex: 37745 	Time (ep_freq): 0:00:00.81 	Time (total): 0:15:51.13
# EP: 28400 	Steps: 7 	MemoryIndex: 38506 	Time (ep_freq): 0:00:00.80 	Time (total): 0:15:58.68
# EP: 28500 	Steps: 5 	MemoryIndex: 39294 	Time (ep_freq): 0:00:00.90 	Time (total): 0:16:06.49
# EP: 28600 	Steps: 13 	MemoryIndex: 40133 	Time (ep_freq): 0:00:01.01 	Time (total): 0:16:14.50
# EP: 28700 	Steps: 6 	MemoryIndex: 40888 	Time (ep_freq): 0:00:00.81 	Time (total): 0:16:22.54
# EP: 28800 	Steps: 5 	MemoryIndex: 41641 	Time (ep_freq): 0:00:00.74 	Time (total): 0:16:30.58
# EP: 28900 	Steps: 5 	MemoryIndex: 42386 	Time (ep_freq): 0:00:00.78 	Time (total): 0:16:38.82
# EP: 29000 	Steps: 6 	MemoryIndex: 43128 	Time (ep_freq): 0:00:00.78 	Time (total): 0:16:47.19
# EP: 29100 	Steps: 5 	MemoryIndex: 43840 	Time (ep_freq): 0:00:00.78 	Time (total): 0:16:55.72
# EP: 29200 	Steps: 18 	MemoryIndex: 44621 	Time (ep_freq): 0:00:00.80 	Time (total): 0:17:04.37
# EP: 29300 	Steps: 5 	MemoryIndex: 45318 	Time (ep_freq): 0:00:00.70 	Time (total): 0:17:13.06
# EP: 29400 	Steps: 7 	MemoryIndex: 46154 	Time (ep_freq): 0:00:01.02 	Time (total): 0:17:22.66
# EP: 29500 	Steps: 20 	MemoryIndex: 46981 	Time (ep_freq): 0:00:01.05 	Time (total): 0:17:31.98
# EP: 29600 	Steps: 6 	MemoryIndex: 47718 	Time (ep_freq): 0:00:00.72 	Time (total): 0:17:41.11
# EP: 29700 	Steps: 6 	MemoryIndex: 48478 	Time (ep_freq): 0:00:00.75 	Time (total): 0:17:50.40
# EP: 29800 	Steps: 7 	MemoryIndex: 49319 	Time (ep_freq): 0:00:01.05 	Time (total): 0:18:00.11
# EP: 29900 	Steps: 7 	MemoryIndex: 50063 	Time (ep_freq): 0:00:00.82 	Time (total): 0:18:09.70
# EP: 30000 	Steps: 5 	MemoryIndex: 50799 	Time (ep_freq): 0:00:00.81 	Time (total): 0:18:19.49
# EP: 30100 	Steps: 5 	MemoryIndex: 51553 	Time (ep_freq): 0:00:00.94 	Time (total): 0:18:29.51
# EP: 30200 	Steps: 7 	MemoryIndex: 52303 	Time (ep_freq): 0:00:00.80 	Time (total): 0:18:39.54
# EP: 30300 	Steps: 6 	MemoryIndex: 53137 	Time (ep_freq): 0:00:00.90 	Time (total): 0:18:49.80
# EP: 30400 	Steps: 8 	MemoryIndex: 53932 	Time (ep_freq): 0:00:00.87 	Time (total): 0:19:00.17
# EP: 30500 	Steps: 6 	MemoryIndex: 54726 	Time (ep_freq): 0:00:00.77 	Time (total): 0:19:10.58
# EP: 30600 	Steps: 6 	MemoryIndex: 55440 	Time (ep_freq): 0:00:00.69 	Time (total): 0:19:21.18
# EP: 30700 	Steps: 20 	MemoryIndex: 56295 	Time (ep_freq): 0:00:00.95 	Time (total): 0:19:32.07
# EP: 30800 	Steps: 8 	MemoryIndex: 57042 	Time (ep_freq): 0:00:00.76 	Time (total): 0:19:42.92
# EP: 30900 	Steps: 7 	MemoryIndex: 57906 	Time (ep_freq): 0:00:00.99 	Time (total): 0:19:54.14
# EP: 31000 	Steps: 17 	MemoryIndex: 58737 	Time (ep_freq): 0:00:00.96 	Time (total): 0:20:05.48
# EP: 31100 	Steps: 7 	MemoryIndex: 59468 	Time (ep_freq): 0:00:00.77 	Time (total): 0:20:16.79
# EP: 31200 	Steps: 7 	MemoryIndex: 60227 	Time (ep_freq): 0:00:00.88 	Time (total): 0:20:28.30
# EP: 31300 	Steps: 6 	MemoryIndex: 60945 	Time (ep_freq): 0:00:00.68 	Time (total): 0:20:39.75
# EP: 31400 	Steps: 6 	MemoryIndex: 61781 	Time (ep_freq): 0:00:01.01 	Time (total): 0:20:52.44
# EP: 31500 	Steps: 20 	MemoryIndex: 62552 	Time (ep_freq): 0:00:00.79 	Time (total): 0:21:04.27
# EP: 31600 	Steps: 6 	MemoryIndex: 63352 	Time (ep_freq): 0:00:00.97 	Time (total): 0:21:16.39
# EP: 31700 	Steps: 6 	MemoryIndex: 64067 	Time (ep_freq): 0:00:00.72 	Time (total): 0:21:28.45
# EP: 31800 	Steps: 5 	MemoryIndex: 64892 	Time (ep_freq): 0:00:00.94 	Time (total): 0:21:40.80
# EP: 31900 	Steps: 6 	MemoryIndex: 65749 	Time (ep_freq): 0:00:01.01 	Time (total): 0:21:53.38
# EP: 32000 	Steps: 7 	MemoryIndex: 66542 	Time (ep_freq): 0:00:00.91 	Time (total): 0:22:06.04
# EP: 32100 	Steps: 5 	MemoryIndex: 67328 	Time (ep_freq): 0:00:00.75 	Time (total): 0:22:18.65
# EP: 32200 	Steps: 5 	MemoryIndex: 68104 	Time (ep_freq): 0:00:00.88 	Time (total): 0:22:32.05
# EP: 32300 	Steps: 7 	MemoryIndex: 68854 	Time (ep_freq): 0:00:00.81 	Time (total): 0:22:45.06
# EP: 32400 	Steps: 8 	MemoryIndex: 69615 	Time (ep_freq): 0:00:00.85 	Time (total): 0:22:58.31
# EP: 32500 	Steps: 6 	MemoryIndex: 70291 	Time (ep_freq): 0:00:00.64 	Time (total): 0:23:11.41
# EP: 32600 	Steps: 8 	MemoryIndex: 71060 	Time (ep_freq): 0:00:00.80 	Time (total): 0:23:24.74
# EP: 32700 	Steps: 6 	MemoryIndex: 71764 	Time (ep_freq): 0:00:00.85 	Time (total): 0:23:38.31
# EP: 32800 	Steps: 6 	MemoryIndex: 72540 	Time (ep_freq): 0:00:00.87 	Time (total): 0:23:52.01
# EP: 32900 	Steps: 6 	MemoryIndex: 73305 	Time (ep_freq): 0:00:00.89 	Time (total): 0:24:05.89
# EP: 33000 	Steps: 6 	MemoryIndex: 74153 	Time (ep_freq): 0:00:00.85 	Time (total): 0:24:19.90
# EP: 33100 	Steps: 5 	MemoryIndex: 74864 	Time (ep_freq): 0:00:00.75 	Time (total): 0:24:33.95
# EP: 33200 	Steps: 5 	MemoryIndex: 75602 	Time (ep_freq): 0:00:00.82 	Time (total): 0:24:48.16
# EP: 33300 	Steps: 7 	MemoryIndex: 76468 	Time (ep_freq): 0:00:01.06 	Time (total): 0:25:02.76
# EP: 33400 	Steps: 6 	MemoryIndex: 77190 	Time (ep_freq): 0:00:00.80 	Time (total): 0:25:17.28
# EP: 33500 	Steps: 6 	MemoryIndex: 77962 	Time (ep_freq): 0:00:00.82 	Time (total): 0:25:31.99
# EP: 33600 	Steps: 11 	MemoryIndex: 78649 	Time (ep_freq): 0:00:00.65 	Time (total): 0:25:46.60
# EP: 33700 	Steps: 7 	MemoryIndex: 79345 	Time (ep_freq): 0:00:00.81 	Time (total): 0:26:02.17
# EP: 33800 	Steps: 8 	MemoryIndex: 80095 	Time (ep_freq): 0:00:00.82 	Time (total): 0:26:17.33
# EP: 33900 	Steps: 5 	MemoryIndex: 80806 	Time (ep_freq): 0:00:00.72 	Time (total): 0:26:32.39
# EP: 34000 	Steps: 6 	MemoryIndex: 81533 	Time (ep_freq): 0:00:00.74 	Time (total): 0:26:47.66
# EP: 34100 	Steps: 7 	MemoryIndex: 82246 	Time (ep_freq): 0:00:00.65 	Time (total): 0:27:03.02
# EP: 34200 	Steps: 6 	MemoryIndex: 82940 	Time (ep_freq): 0:00:00.82 	Time (total): 0:27:18.69
# EP: 34300 	Steps: 20 	MemoryIndex: 83648 	Time (ep_freq): 0:00:00.80 	Time (total): 0:27:34.68
# EP: 34400 	Steps: 6 	MemoryIndex: 84383 	Time (ep_freq): 0:00:00.78 	Time (total): 0:27:50.59
# EP: 34500 	Steps: 6 	MemoryIndex: 85104 	Time (ep_freq): 0:00:00.73 	Time (total): 0:28:06.45
# EP: 34600 	Steps: 20 	MemoryIndex: 85786 	Time (ep_freq): 0:00:00.62 	Time (total): 0:28:22.35
# EP: 34700 	Steps: 7 	MemoryIndex: 810 	Time (ep_freq): 0:00:00.91 	Time (total): 0:28:23.35
# EP: 34800 	Steps: 7 	MemoryIndex: 1524 	Time (ep_freq): 0:00:00.70 	Time (total): 0:28:24.20
# EP: 34900 	Steps: 5 	MemoryIndex: 2297 	Time (ep_freq): 0:00:00.79 	Time (total): 0:28:25.28
# EP: 35000 	Steps: 7 	MemoryIndex: 3065 	Time (ep_freq): 0:00:00.82 	Time (total): 0:28:26.54
# EP: 35100 	Steps: 5 	MemoryIndex: 3831 	Time (ep_freq): 0:00:00.84 	Time (total): 0:28:27.93
# EP: 35200 	Steps: 6 	MemoryIndex: 4554 	Time (ep_freq): 0:00:00.83 	Time (total): 0:28:29.48
# EP: 35300 	Steps: 6 	MemoryIndex: 5251 	Time (ep_freq): 0:00:00.62 	Time (total): 0:28:30.93
# EP: 35400 	Steps: 20 	MemoryIndex: 5944 	Time (ep_freq): 0:00:00.66 	Time (total): 0:28:32.55
# EP: 35500 	Steps: 20 	MemoryIndex: 6762 	Time (ep_freq): 0:00:00.97 	Time (total): 0:28:34.61
# EP: 35600 	Steps: 6 	MemoryIndex: 7461 	Time (ep_freq): 0:00:00.67 	Time (total): 0:28:36.52
# EP: 35700 	Steps: 5 	MemoryIndex: 8198 	Time (ep_freq): 0:00:00.68 	Time (total): 0:28:38.56
# EP: 35800 	Steps: 6 	MemoryIndex: 9017 	Time (ep_freq): 0:00:00.82 	Time (total): 0:28:40.88
# EP: 35900 	Steps: 6 	MemoryIndex: 9748 	Time (ep_freq): 0:00:00.73 	Time (total): 0:28:43.26
# EP: 36000 	Steps: 6 	MemoryIndex: 10578 	Time (ep_freq): 0:00:00.83 	Time (total): 0:28:45.86
# EP: 36100 	Steps: 6 	MemoryIndex: 11301 	Time (ep_freq): 0:00:00.71 	Time (total): 0:28:48.48
# EP: 36200 	Steps: 6 	MemoryIndex: 12077 	Time (ep_freq): 0:00:00.86 	Time (total): 0:28:51.41
# EP: 36300 	Steps: 6 	MemoryIndex: 12845 	Time (ep_freq): 0:00:00.75 	Time (total): 0:28:54.37
# EP: 36400 	Steps: 6 	MemoryIndex: 13581 	Time (ep_freq): 0:00:00.77 	Time (total): 0:28:57.51
# EP: 36500 	Steps: 6 	MemoryIndex: 14453 	Time (ep_freq): 0:00:00.99 	Time (total): 0:29:00.97
# EP: 36600 	Steps: 6 	MemoryIndex: 15217 	Time (ep_freq): 0:00:00.74 	Time (total): 0:29:04.34
# EP: 36700 	Steps: 5 	MemoryIndex: 16052 	Time (ep_freq): 0:00:00.96 	Time (total): 0:29:08.07
# EP: 36800 	Steps: 6 	MemoryIndex: 16782 	Time (ep_freq): 0:00:00.78 	Time (total): 0:29:11.79
# EP: 36900 	Steps: 6 	MemoryIndex: 17474 	Time (ep_freq): 0:00:00.66 	Time (total): 0:29:15.51
# EP: 37000 	Steps: 7 	MemoryIndex: 698 	Time (ep_freq): 0:00:00.70 	Time (total): 0:29:16.23
# EP: 37100 	Steps: 6 	MemoryIndex: 1446 	Time (ep_freq): 0:00:00.80 	Time (total): 0:29:17.16
# EP: 37200 	Steps: 9 	MemoryIndex: 2278 	Time (ep_freq): 0:00:00.87 	Time (total): 0:29:18.31
# EP: 37300 	Steps: 7 	MemoryIndex: 2976 	Time (ep_freq): 0:00:00.65 	Time (total): 0:29:19.38
# EP: 37400 	Steps: 7 	MemoryIndex: 3736 	Time (ep_freq): 0:00:00.72 	Time (total): 0:29:20.65
# EP: 37500 	Steps: 6 	MemoryIndex: 4606 	Time (ep_freq): 0:00:00.85 	Time (total): 0:29:22.20
# EP: 37600 	Steps: 6 	MemoryIndex: 5313 	Time (ep_freq): 0:00:00.68 	Time (total): 0:29:23.73
# EP: 37700 	Steps: 7 	MemoryIndex: 6095 	Time (ep_freq): 0:00:00.85 	Time (total): 0:29:25.55
# EP: 37800 	Steps: 20 	MemoryIndex: 6905 	Time (ep_freq): 0:00:00.82 	Time (total): 0:29:27.48
# EP: 37900 	Steps: 7 	MemoryIndex: 7693 	Time (ep_freq): 0:00:00.82 	Time (total): 0:29:29.55
# EP: 38000 	Steps: 8 	MemoryIndex: 8480 	Time (ep_freq): 0:00:00.84 	Time (total): 0:29:31.78
# EP: 38100 	Steps: 5 	MemoryIndex: 9171 	Time (ep_freq): 0:00:00.64 	Time (total): 0:29:33.95
# EP: 38200 	Steps: 6 	MemoryIndex: 9871 	Time (ep_freq): 0:00:00.66 	Time (total): 0:29:36.32
# EP: 38300 	Steps: 7 	MemoryIndex: 10564 	Time (ep_freq): 0:00:00.65 	Time (total): 0:29:38.75
# EP: 38400 	Steps: 5 	MemoryIndex: 716 	Time (ep_freq): 0:00:00.72 	Time (total): 0:29:39.49
# EP: 38500 	Steps: 6 	MemoryIndex: 1475 	Time (ep_freq): 0:00:00.87 	Time (total): 0:29:40.49
# EP: 38600 	Steps: 20 	MemoryIndex: 2269 	Time (ep_freq): 0:00:00.90 	Time (total): 0:29:41.68
# EP: 38700 	Steps: 7 	MemoryIndex: 2999 	Time (ep_freq): 0:00:00.78 	Time (total): 0:29:42.88
# EP: 38800 	Steps: 6 	MemoryIndex: 3742 	Time (ep_freq): 0:00:00.75 	Time (total): 0:29:44.17
# EP: 38900 	Steps: 6 	MemoryIndex: 4471 	Time (ep_freq): 0:00:00.74 	Time (total): 0:29:45.61
# EP: 39000 	Steps: 7 	MemoryIndex: 5219 	Time (ep_freq): 0:00:00.74 	Time (total): 0:29:47.16
# EP: 39100 	Steps: 6 	MemoryIndex: 5965 	Time (ep_freq): 0:00:00.72 	Time (total): 0:29:48.83
# EP: 39200 	Steps: 6 	MemoryIndex: 6807 	Time (ep_freq): 0:00:00.92 	Time (total): 0:29:50.83
# EP: 39300 	Steps: 6 	MemoryIndex: 7570 	Time (ep_freq): 0:00:00.75 	Time (total): 0:29:52.82
# EP: 39400 	Steps: 8 	MemoryIndex: 8362 	Time (ep_freq): 0:00:00.87 	Time (total): 0:29:55.06
# EP: 39500 	Steps: 5 	MemoryIndex: 9077 	Time (ep_freq): 0:00:00.63 	Time (total): 0:29:57.21
# EP: 39600 	Steps: 6 	MemoryIndex: 9863 	Time (ep_freq): 0:00:00.86 	Time (total): 0:29:59.73
# EP: 39700 	Steps: 6 	MemoryIndex: 10667 	Time (ep_freq): 0:00:00.88 	Time (total): 0:30:02.40
# EP: 39800 	Steps: 6 	MemoryIndex: 11398 	Time (ep_freq): 0:00:00.70 	Time (total): 0:30:05.05
# EP: 39900 	Steps: 6 	MemoryIndex: 12191 	Time (ep_freq): 0:00:00.76 	Time (total): 0:30:07.89
# EP: 40000 	Steps: 9 	MemoryIndex: 12953 	Time (ep_freq): 0:00:00.81 	Time (total): 0:30:10.88
# ...Training Ended
# at  2020-05-01 18:39:41.720953
